# %% [markdown]
# # SAF Project Environment Test

# %%
# PROJECT: Designed and Executed by ADAMO for Air France - SAF Project

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import lightgbm as lgb
import xgboost as xgb
import shap, optuna, statsmodels.api as sm
import plotly.express as px

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %% [markdown]
# # Plot test for SAF Project

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(6,4))
sns.lineplot(x=x, y=y, color="teal")
plt.title("Environment Test Plot - SAF Project")
plt.xlabel("X values")
plt.ylabel("sin(X)")
plt.show()
